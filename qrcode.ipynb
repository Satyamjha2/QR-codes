# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.moduledrawers import RoundedModuleDrawer
from qrcode.image.styles.colormasks import RadialGradiantColorMask
from qrcode.image.styles.moduledrawers import VerticalBarsDrawer

# %%
qr = qrcode.QRCode(version=1,error_correction=qrcode.constants.ERROR_CORRECT_H,box_size=20,border=1)

#qr = qrcode.QRCode(error_correction=qrcode.constants.ERROR_CORRECT_L)
qr.add_data('Some data')

#img_1 = qr.make_image(image_factory=StyledPilImage, modbule_drawer=RoundedModuleDrawer())
#img_2 = qr.make_image(image_factory=StyledPilImage, color_mask=RadialGradiantColorMask())
img_4 = qr.make_image(image_factory=StyledPilImage, module_drawer=VerticalBarsDrawer())
#img_5 = qr.make_image(image_factory=StyledPilImage, module_drawer=CircleModuleDrawer())
#img_6 = qr.make_image(image_factory=StyledPilImage, module_drawer=GappedCircleModuleDrawer())

#img_3 = qr.make_image(image_factory=StyledPilImage, embeded_image_path="C:/Users/jhash/Pictures/generative_pics/Pictor/image.png")

# %%
plt.axis('off')
plt.imshow(img_4)
plt.savefig('C:/Users/jhash/Pictures/generative_pics/Pictor/qrcode3.png',dpi=300, bbox_inches='tight',pad_inches=0)

# %%
plt.axis('off')
plt.imshow(img_4)

# %%
plt.axis('off')
#plt.imshow(img_1)
plt.imshow(img_1,interpolation='bicubic',cmap='nipy_spectral')
plt.savefig('C:/Users/jhash/Pictures/generative_pics/Pictor/qrcode.png',dpi=300, bbox_inches='tight')

# %%
plt.imshow(img_2)

# %%
file="C:/Users/jhash/Pictures/generative_pics/Pictor/image.png"
img_3 = qr.make_image(image_factory=StyledPilImage, embeded_image_path=file)

# %%
plt.imshow(img_3)

# %%
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=1,
    border=1
)
qr.add_data('test text')
qr.make()
img = qr.make_image()
print(np.shape(img))
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(img)
plt.savefig('C:/Users/jhash/Pictures/generative_pics/Pictor/qrcode2.png', bbox_inches='tight',pad_inches=0)
#plt.show()
# Out:
# (27, 27)

# %%
qr = qrcode.QRCode(
    version=2,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=1,
    border=0
)
qr.add_data("Some text")
mat=qr.get_matrix()
#mat = int(mat == 'true')
print(np.shape(mat))
print(mat[1][2])
print(mat)
# Out:
# (25, 25)
# False
# ...
